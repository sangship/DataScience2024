# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 위의 코드를 시작하고 나서, 세션 다시 시작
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (35.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
#폰트 설정

import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
# from google.colab import drive
# drive.mount('/content/drive')

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
csvPath = "/content/drive/MyDrive/새싹강동3기구글AI과정/code/DataScience/4_데이터분석예제/data/등록인구_20240807134714.csv"


pop_Seoul = pd.read_csv(csvPath, encoding='utf-8')
pop_Seoul.head()
# Out:
#    동별(1)  동별(2) 2024 2/4 2024 2/4.1 2024 2/4.2 2024 2/4.3 2024 2/4.4  \
# 0  동별(1)  동별(2)  세대 (세대)      계 (명)      계 (명)      계 (명)    한국인 (명)
# 1  동별(1)  동별(2)       소계         소계         남자         여자         소계
# 2     합계     소계  4486014    9619861    4634458    4985403    9366283
# 3     합계    종로구    72394     150204      71684      78520     139189
# 4     합계     중구    65273     131800      63383      68417     121475
#
#   2024 2/4.5 2024 2/4.6 2024 2/4.7 2024 2/4.8 2024 2/4.9 2024 2/4.10  \
# 0    한국인 (명)    한국인 (명)  등록외국인 (명)  등록외국인 (명)  등록외국인 (명)   세대당인구 (명)
# 1         남자         여자         소계         남자         여자          소계
# 2    4524862    4841421     253578     109596     143982        2.09
# 3      67005      72184      11015       4679       6336        1.92
# 4      58582      62893      10325       4801       5524        1.86
#
#     2024 2/4.11
# 0  65세이상고령자 (명)
# 1            소계
# 2       1785286
# 3         29338
# 4         26516

# %%
pop_Seoul.loc[0]
# Out:
# 동별(1)                 동별(1)
# 동별(2)                 동별(2)
# 2024 2/4            세대 (세대)
# 2024 2/4.1            계 (명)
# 2024 2/4.2            계 (명)
# 2024 2/4.3            계 (명)
# 2024 2/4.4          한국인 (명)
# 2024 2/4.5          한국인 (명)
# 2024 2/4.6          한국인 (명)
# 2024 2/4.7        등록외국인 (명)
# 2024 2/4.8        등록외국인 (명)
# 2024 2/4.9        등록외국인 (명)
# 2024 2/4.10       세대당인구 (명)
# 2024 2/4.11    65세이상고령자 (명)
# Name: 0, dtype: object

# %%
pop_Seoul.columns = pop_Seoul.loc[0]
pop_Seoul.head()
# Out:
# 0  동별(1)  동별(2)  세대 (세대)    계 (명)    계 (명)    계 (명)  한국인 (명)  한국인 (명)  \
# 0  동별(1)  동별(2)  세대 (세대)    계 (명)    계 (명)    계 (명)  한국인 (명)  한국인 (명)
# 1  동별(1)  동별(2)       소계       소계       남자       여자       소계       남자
# 2     합계     소계  4486014  9619861  4634458  4985403  9366283  4524862
# 3     합계    종로구    72394   150204    71684    78520   139189    67005
# 4     합계     중구    65273   131800    63383    68417   121475    58582
#
# 0  한국인 (명)  등록외국인 (명)  등록외국인 (명)  등록외국인 (명)  세대당인구 (명)  65세이상고령자 (명)
# 0  한국인 (명)  등록외국인 (명)  등록외국인 (명)  등록외국인 (명)  세대당인구 (명)  65세이상고령자 (명)
# 1       여자         소계         남자         여자         소계            소계
# 2  4841421     253578     109596     143982       2.09       1785286
# 3    72184      11015       4679       6336       1.92         29338
# 4    62893      10325       4801       5524       1.86         26516

# %%
pop_Seoul = pop_Seoul.drop(0)
pop_Seoul.head()
# Out:
# 0  동별(1)  동별(2)  세대 (세대)    계 (명)    계 (명)    계 (명)  한국인 (명)  한국인 (명)  \
# 1  동별(1)  동별(2)       소계       소계       남자       여자       소계       남자
# 2     합계     소계  4486014  9619861  4634458  4985403  9366283  4524862
# 3     합계    종로구    72394   150204    71684    78520   139189    67005
# 4     합계     중구    65273   131800    63383    68417   121475    58582
# 5     합계    용산구   104187   219451   105752   113699   206061    98564
#
# 0  한국인 (명) 등록외국인 (명) 등록외국인 (명) 등록외국인 (명) 세대당인구 (명) 65세이상고령자 (명)
# 1       여자        소계        남자        여자        소계           소계
# 2  4841421    253578    109596    143982      2.09      1785286
# 3    72184     11015      4679      6336      1.92        29338
# 4    62893     10325      4801      5524      1.86        26516
# 5   107497     13390      7188      6202      1.98        39021

# %%
# 불필요한 컬럼 삭제
# iloc를 이용해서 컬럼 골라 내기
# [1, 3, 6, 9, 13]

pop_Seoul = pop_Seoul.iloc[:, [1, 3, 6, 9, 13]]
pop_Seoul.head()
# Out:
# 0  동별(2)    계 (명)  한국인 (명) 등록외국인 (명) 65세이상고령자 (명)
# 1  동별(2)       소계       소계        소계           소계
# 2     소계  9619861  9366283    253578      1785286
# 3    종로구   150204   139189     11015        29338
# 4     중구   131800   121475     10325        26516
# 5    용산구   219451   206061     13390        39021

# %%
# 컬럼명 바꾸기
pop_Seoul.columns = ['구별', '인구수', '한국인', '외국인', '고령자']
pop_Seoul.head()
# Out:
#       구별      인구수      한국인     외국인      고령자
# 1  동별(2)       소계       소계      소계       소계
# 2     소계  9619861  9366283  253578  1785286
# 3    종로구   150204   139189   11015    29338
# 4     중구   131800   121475   10325    26516
# 5    용산구   219451   206061   13390    39021

# %%
# 1행, 2행 삭제
pop_Seoul = pop_Seoul.drop([1, 2])
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 3  종로구  150204  139189  11015  29338
# 4   중구  131800  121475  10325  26516
# 5  용산구  219451  206061  13390  39021
# 6  성동구  283853  276597   7256  50534
# 7  광진구  350005  334159  15846  58307

# %%
#인덱스를 0부터 시작하도록 초기화

pop_Seoul = pop_Seoul.reset_index(drop=True)
pop_Seoul.head()
# Out:
#     구별     인구수     한국인    외국인    고령자
# 0  종로구  150204  139189  11015  29338
# 1   중구  131800  121475  10325  26516
# 2  용산구  219451  206061  13390  39021
# 3  성동구  283853  276597   7256  50534
# 4  광진구  350005  334159  15846  58307

# %%
pop_Seoul
# Out:
#       구별     인구수     한국인    외국인     고령자
# 0    종로구  150204  139189  11015   29338
# 1     중구  131800  121475  10325   26516
# 2    용산구  219451  206061  13390   39021
# 3    성동구  283853  276597   7256   50534
# 4    광진구  350005  334159  15846   58307
# 5   동대문구  360066  341345  18721   68503
# 6    중랑구  386782  381126   5656   81160
# 7    성북구  436666  424194  12472   81965
# 8    강북구  290252  285054   5198   69922
# 9    도봉구  308060  305400   2660   72365
# 10   노원구  500045  495183   4862   98515
# 11   은평구  468976  464738   4238   96177
# 12  서대문구  320010  305369  14641   59275
# 13   마포구  373980  363029  10951   59004
# 14   양천구  436595  433307   3288   78399
# 15   강서구  565133  559335   5798  105023
# 16   구로구  413099  390169  22930   81973
# 17   금천구  240153  226672  13481   46764
# 18  영등포구  397771  375040  22731   69230
# 19   동작구  389541  378324  11217   71823
# 20   관악구  497632  481145  16487   87267
# 21   서초구  411959  407404   4555   67191
# ...

# %%
# 서울시 자치구 (연도별) CCTV 설치현황 데이터 불러오기

xlsxPath = '/content/drive/MyDrive/새싹강동3기구글AI과정/code/DataScience/4_데이터분석예제/data/서울시 자치구 (연도별) CCTV 설치현황_240630.xlsx'

#엑셀파일 불러오기
CCTV_Seoul = pd.read_excel(xlsxPath, header=2, usecols='C, D, E, F, G, H, I, J, K, L, M, N', encoding='utf-8')
CCTV_Seoul.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-89f0452d71f9> in <cell line: 6>()
#       4
#       5 #엑셀파일 불러오기
# ----> 6 CCTV_Seoul = pd.read_excel(xlsxPath, header=2, usecols='C, D, E, F, G, H, I, J, K, L, M, N', encoding='utf-8')
#       7 CCTV_Seoul.head()
#       8
#
# TypeError: read_excel() got an unexpected keyword argument 'encoding'

# %%
CCTV_Seoul = CCTV_Seoul.drop([0])
CCTV_Seoul.head()
# Out:
#     구분   총 계  2016년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  \
# 1  종로구  2290                 230    100    140    140     66    233     85
# 2  중 구  3021                 376    220    366    381    155    357    414
# 3  용산구  3300                 106    295    491    147    335    473    486
# 4  성동구  4514                 542    278    939    457    640    483    366
# 5  광진구  4156                 403     42    666    460    712    191    740
#
#    2022년  2023년  2024년\n6.30.
# 1    219    919           158
# 2    137    135           480
# 3    413    492            62
# 4    233    471           105
# 5    273    340           329

# %%
#index초기화

CCTV_Seoul = CCTV_Seoul.reset_index(drop=True)
CCTV_Seoul.head()
# Out:
#     구분   총 계  2016년 이전 설치된 CCTV   2016년  2017년  2018년  2019년  2020년  2021년  \
# 0  종로구  2290                 230    100    140    140     66    233     85
# 1  중 구  3021                 376    220    366    381    155    357    414
# 2  용산구  3300                 106    295    491    147    335    473    486
# 3  성동구  4514                 542    278    939    457    640    483    366
# 4  광진구  4156                 403     42    666    460    712    191    740
#
#    2022년  2023년  2024년\n6.30.
# 0    219    919           158
# 1    137    135           480
# 2    413    492            62
# 3    233    471           105
# 4    273    340           329

# %%
CCTV_Seoul.columns = ['구별', 'CCTV대수', '2016년이전CCTV ', '2016년', '2017년', '2018년', '2019년',
       '2020년', '2021년', '2022년', '2023년', '2024년2분기']

# %%
CCTV_Seoul.head()
# Out:
#     구별  CCTV대수  2016년이전CCTV   2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 0  종로구    2290           230    100    140    140     66    233     85    219
# 1  중 구    3021           376    220    366    381    155    357    414    137
# 2  용산구    3300           106    295    491    147    335    473    486    413
# 3  성동구    4514           542    278    939    457    640    483    366    233
# 4  광진구    4156           403     42    666    460    712    191    740    273
#
#    2023년  2024년2분기
# 0    919       158
# 1    135       480
# 2    492        62
# 3    471       105
# 4    340       329

# %%
#pop_Seoul, CCTV_Seoul 데이터 프레임 merge

pop_CCTV = pd.merge(pop_Seoul, CCTV_Seoul, on='구별')


pop_CCTV.head()
# Out:
#      구별     인구수     한국인    외국인    고령자  CCTV대수  2016년이전CCTV   2016년  2017년  \
# 0   종로구  150204  139189  11015  29338    2290           230    100    140
# 1   용산구  219451  206061  13390  39021    3300           106    295    491
# 2   성동구  283853  276597   7256  50534    4514           542    278    939
# 3   광진구  350005  334159  15846  58307    4156           403     42    666
# 4  동대문구  360066  341345  18721  68503    3446             0    657    670
#
#    2018년  2019년  2020년  2021년  2022년  2023년  2024년2분기
# 0    140     66    233     85    219    919       158
# 1    147    335    473    486    413    492        62
# 2    457    640    483    366    233    471       105
# 3    460    712    191    740    273    340       329
# 4    199    215    229    226    317    755       178

# %%
xlsxPath ='/content/drive/MyDrive/새싹강동3기구글AI과정/code/DataScience/4_데이터분석예제/data/서울시 자치구 (목적별) CCTV 설치현황_240630.xlsx'


CCTV_Seoul2 = pd.read_excel(xlsxPath, header = 2)

CCTV_Seoul2
# Out:
#     Unnamed: 0   구 분   CCTV 총계 범죄예방 및 수사 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0          NaN   NaN       NaN       소 계         방범  어린이\n보호구역     공원·놀이터
# 1          NaN  자치구   102380.0     89459      70539       8512       9582
# 2          NaN   종로구    2290.0      2154       1779        105        270
# 3          NaN    중구    3021.0      2460       2032         76        290
# 4          NaN   용산구    3300.0      2938       2484        233        221
# 5          NaN   성동구    4514.0      3971       2932        421        384
# 6          NaN   광진구    4156.0      3722       2568        554        535
# 7          NaN   동대문    3446.0      3210       2552        285        341
# 8          NaN   중랑구    4512.0      4163       3821        141        190
# 9          NaN   성북구    4543.0      4181       3457        451        273
# 10         NaN   강북구    3584.0      3430       2881        355        194
# 11         NaN   도봉구    2378.0      2196       1670        192        334
# ...

# %%
# xlsxPath ='/content/drive/MyDrive/새싹강동3기구글AI과정/code/DataScience/4_데이터분석예제/data/서울시 자치구 (목적별) CCTV 설치현황_240630.xlsx'


CCTV_Seoul2 = pd.read_excel(xlsxPath, header=2, usecols='B,D,E,F,G,H')

CCTV_Seoul2.columns = ['구별', 'CCTV총대수', '방범CCTV ', '어린이보호구역CCTV', '공원놀이터CCTV', '쓰레기무단투기CCTV']

CCTV_Seoul2.head()
# Out:
#      구별 CCTV총대수 방범CCTV  어린이보호구역CCTV 공원놀이터CCTV 쓰레기무단투기CCTV
# 0  자치구    89459   70539        8512      9582         826
# 1   종로구    2154    1779         105       270           0
# 2    중구    2460    2032          76       290          62
# 3   용산구    2938    2484         233       221           0
# 4   성동구    3971    2932         421       384         234

# %%
#0번행 삭제
CCTV_Seoul2 = CCTV_Seoul2.drop([0])

# %%
CCTV_Seoul2.head()
# Out:
#     구별 CCTV총대수 방범CCTV  어린이보호구역CCTV 공원놀이터CCTV 쓰레기무단투기CCTV
# 1  종로구    2154    1779         105       270           0
# 2   중구    2460    2032          76       290          62
# 3  용산구    2938    2484         233       221           0
# 4  성동구    3971    2932         421       384         234
# 5  광진구    3722    2568         554       535          65

# %%
#인덱스 리셋
CCTV_Seoul2 = CCTV_Seoul2.reset_index(drop=True)
CCTV_Seoul2.head()
# Out:
#     구별 CCTV총대수 방범CCTV  어린이보호구역CCTV 공원놀이터CCTV 쓰레기무단투기CCTV
# 0  종로구    2154    1779         105       270           0
# 1   중구    2460    2032          76       290          62
# 2  용산구    2938    2484         233       221           0
# 3  성동구    3971    2932         421       384         234
# 4  광진구    3722    2568         554       535          65

# %%
CCTV_Seoul2
# Out:
#      구별 CCTV총대수 방범CCTV  어린이보호구역CCTV 공원놀이터CCTV 쓰레기무단투기CCTV
# 0   종로구    2154    1779         105       270           0
# 1    중구    2460    2032          76       290          62
# 2   용산구    2938    2484         233       221           0
# 3   성동구    3971    2932         421       384         234
# 4   광진구    3722    2568         554       535          65
# 5   동대문    3210    2552         285       341          32
# 6   중랑구    4163    3821         141       190          11
# 7   성북구    4181    3457         451       273           0
# 8   강북구    3430    2881         355       194           0
# 9   도봉구    2196    1670         192       334           0
# 10  노원구    2716    1625         302       683         106
# 11  은평구    4369    3697          97       575           0
# 12  서대문    3117    2348         132       637           0
# 13  마포구    3217    2710         227       240          40
# 14  양천구    4064    2698         829       537           0
# ...
